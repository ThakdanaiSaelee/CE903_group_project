# %% [markdown]
# # Data Preparation
# The variable x_train contains 3 EEG channels, 140 trials with 9 seconds each. Each trial has 1152 units of data. Thus, each second in a trial produces 128 units of signal data. The variable y_train contains the classlabels ‘1’, ‘2’ for left and right, respectively. x_test contains another set of 140 trials. The cue was presented from t = 3s to 9s. At the same time, the feedback was presented to the subject. Within this period, it should be possible to distinguish the two types of trials.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('x_train.csv', header=None)
data.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.010254  0.081055  0.062500 -0.091797 -0.057617 -0.084473  0.056641
# 1 -0.023926  0.076172  0.034180 -0.080078 -0.026367 -0.105960  0.009277
# 2 -0.009766  0.077637  0.065918 -0.073730  0.004883 -0.086426 -0.078613
# 3  0.048828  0.112300  0.123050 -0.067871 -0.020996 -0.076172 -0.157230
# 4 -0.038086  0.037109  0.066895 -0.092773 -0.029297 -0.067871 -0.153320
#
#         7         8         9    ...       410       411       412       413  \
# 0  0.061523  0.039062 -0.125490  ...  0.019531  0.045410  0.035156  0.070312
# 1  0.041992  0.031738 -0.114260  ...  0.134770  0.116210  0.073730  0.084473
# 2  0.015625  0.012695 -0.109860  ...  0.162110  0.135740  0.081543  0.042480
# 3 -0.002930 -0.024902 -0.101070  ...  0.160640  0.101560  0.058594  0.003906
# 4 -0.011230 -0.027344 -0.097168  ...  0.144040  0.063965  0.061035 -0.001465
#
#         414       415       416       417       418       419
# 0  0.023926 -0.050293 -0.012207  0.041504  0.044434  0.095703
# 1  0.007812 -0.053711 -0.034668  0.063965  0.070801  0.067871
# 2  0.040527  0.019043 -0.011719  0.050781  0.050293 -0.002441
# 3  0.104980  0.063477 -0.006348  0.053223  0.066895 -0.007812
# 4  0.103030  0.086914  0.011719  0.042480  0.098633  0.025391
#
# [5 rows x 420 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Columns: 420 entries, 0 to 419
# dtypes: float64(420)
# memory usage: 3.7 MB

# %%
data.describe()
# Out:
#                0            1            2            3            4    \
# count  1152.000000  1152.000000  1152.000000  1152.000000  1152.000000
# mean     -0.001096    -0.000807    -0.001366    -0.003607    -0.004327
# std       0.063368     0.069890     0.067713     0.067318     0.066974
# min      -0.181150    -0.219730    -0.252440    -0.258300    -0.268550
# 25%      -0.041138    -0.047485    -0.047852    -0.046387    -0.049316
# 50%      -0.003418    -0.000732    -0.002441    -0.004150    -0.002197
# 75%       0.041626     0.042114     0.046020     0.039551     0.039184
# max       0.225590     0.245610     0.215330     0.279790     0.250490
#
#                5            6            7            8            9    ...  \
# count  1152.000000  1152.000000  1152.000000  1152.000000  1152.000000  ...
# mean     -0.003292     0.001268     0.000935     0.000061     0.001479  ...
# std       0.075070     0.092757     0.073431     0.066523     0.059947  ...
# min      -0.351070    -0.291990    -0.228520    -0.241210    -0.225590  ...
# 25%      -0.047363    -0.056152    -0.046997    -0.041504    -0.038574  ...
# 50%      -0.001953     0.003174     0.003174     0.002197     0.000977  ...
# 75%       0.046020     0.065918     0.050781     0.044434     0.042602  ...
# max       0.264160     0.234380     0.209960     0.196780     0.205080  ...
#
#                410          411          412          413          414  \
# count  1152.000000  1152.000000  1152.000000  1152.000000  1152.000000
# mean     -0.000958    -0.000747     0.002211     0.000488     0.001813
# std       0.125157     0.117597     0.150653     0.121240     0.076571
# min      -0.497560    -0.540040    -0.437500    -0.452640    -0.271970
# 25%      -0.078735    -0.066895    -0.088989    -0.066040    -0.043945
# 50%       0.008789     0.011963     0.000244     0.008545     0.004150
# 75%       0.079102     0.077270     0.091309     0.083008     0.053345
# max       0.377440     0.378420     0.629390     0.382320     0.267090
#
#                415          416          417          418          419
# count  1152.000000  1152.000000  1152.000000  1152.000000  1152.000000
# mean      0.002936     0.001481    -0.000760     0.003910     0.000398
# std       0.081800     0.089683     0.121255     0.104085     0.087604
# min      -0.210940    -0.329100    -0.393070    -0.354490    -0.299800
# 25%      -0.055664    -0.048340    -0.077759    -0.062500    -0.052856
# 50%       0.001221     0.003662     0.007812     0.003906     0.004639
# 75%       0.061523     0.062012     0.091919     0.070801     0.058594
# max       0.256840     0.237790     0.285160     0.297850     0.263180
#
# [8 rows x 420 columns]

# %%
data = data.values
sensor1 = np.zeros((1152,140))
sensor2 = np.zeros((1152,140))
sensor3 = np.zeros((1152,140))
column = 0
for i in range(420):
    if i%3 == 0 :
        sensor1[:,column] = data[:,i]
    elif i%3 == 1:
        sensor2[:,column] = data[:,i]
    elif i%3 == 2:
        sensor3[:,column] = data[:,i]
        column += 1
sensor1 = sensor1.T
sensor2 = sensor2.T
sensor3 = sensor3.T

# %%
sensor1.shape
# Out:
# (140, 1152)

# %%
sensor2.shape
# Out:
# (140, 1152)

# %%
sensor3.shape
# Out:
# (140, 1152)

# %%
print(sensor1)
# Out:
# [[ 0.010254  -0.023926  -0.0097656 ...  0.1084     0.17334    0.22559  ]
#  [-0.091797  -0.080078  -0.07373   ...  0.026855   0.015137   0.019043 ]
#  [ 0.056641   0.0092773 -0.078613  ...  0.013672   0.0063477 -0.038574 ]
#  ...
#  [ 0.04541    0.11621    0.13574   ... -0.065918  -0.050781   0.021484 ]
#  [ 0.023926   0.0078125  0.040527  ... -0.22314   -0.18262   -0.027832 ]
#  [ 0.041504   0.063965   0.050781  ...  0.098145   0.18311    0.18652  ]]

# %%
print(sensor2)
# Out:
# [[ 0.081055   0.076172   0.077637  ...  0.13135    0.18359    0.24561  ]
#  [-0.057617  -0.026367   0.0048828 ...  0.015625   0.023438   0.043945 ]
#  [ 0.061523   0.041992   0.015625  ... -0.025879   0.003418  -0.0083008]
#  ...
#  [ 0.035156   0.07373    0.081543  ... -0.12305   -0.10059   -0.07666  ]
#  [-0.050293  -0.053711   0.019043  ... -0.15674   -0.12012    0.025391 ]
#  [ 0.044434   0.070801   0.050293  ...  0.0048828  0.1582     0.1582   ]]

# %%
print(sensor3)
# Out:
# [[ 0.0625      0.03418     0.065918   ...  0.064941    0.10449
#    0.12939   ]
#  [-0.084473   -0.10596    -0.086426   ...  0.0097656   0.033691
#    0.08252   ]
#  [ 0.039062    0.031738    0.012695   ... -0.020508    0.0058594
#   -0.0073242 ]
#  ...
#  [ 0.070312    0.084473    0.04248    ... -0.04541    -0.063477
#   -0.033691  ]
#  [-0.012207   -0.034668   -0.011719   ... -0.14941    -0.13037
#   -0.00048828]
#  [ 0.095703    0.067871   -0.0024414  ... -0.016113    0.092285
#    0.13379   ]]

# %%
sensor = np.stack((sensor1, sensor2, sensor3), axis = 1)
sensor = sensor.reshape((3,140,1152))
sensor = sensor.reshape(sensor.shape[0], (sensor.shape[1] * sensor.shape[2]))
sensor.shape
# Out:
# (3, 161280)

# %%
ch_names = ['C3', 'Cz', 'C4']

# %%
tmin, tmax = 0, 9 #We are only considering the data after 3 seconds as a decision is only made after that.

# %% [markdown]
# # Converting data to signals
# We are converting the data which is present in the form of a .csv file into a raw signal data for the ease of processing, feature extraction and feature selection.

# %%
# !pip install mne
# !pip install PyQt5
# Out:
# Requirement already satisfied: mne in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (0.24.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from mne) (1.19.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from mne) (1.7.1)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\91974\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: PyQt5 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (5.15.6)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from PyQt5) (12.9.1)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from PyQt5) (5.15.2)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\91974\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
from mne.io import RawArray
import mne
import matplotlib
import PyQt5
info_sensor = mne.create_info(ch_names = ch_names, sfreq = 128, ch_types=['eeg']*3) #The no. of trials are 140 and each trial is sampled at 128 Hz. Hence, sfreq = 128.
raw = RawArray(sensor, info = info_sensor)
#%matplotlib qt
#raw.plot(show_scrollbars=True, show_scalebars=True)
# Out:
# Creating RawArray with float64 data, n_channels=3, n_times=161280
#     Range : 0 ... 161279 =      0.000 ...  1259.992 secs
# Ready.

# %%
'''fig = raw.plot_psd(fmax=64, average=True) # Visualizing Power-Line Noise in channel Cz
fig.subplots_adjust(top=0.85)
fig.suptitle('UnFiltered Cz', size='xx-large', weight='bold')'''
# Out:
# Effective window size : 16.000 (s)
# <MNELineFigure size 720x252 with 1 Axes>
# Text(0.5, 0.98, 'UnFiltered Cz')

# %%
'''raw = raw.copy().filter(8, 26)
fig = raw.plot_psd(fmin=0, fmax=64, average=True)
fig.suptitle('Filtered Data', size='xx-large', weight='bold')'''
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 26 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 26.00 Hz
# - Upper transition bandwidth: 6.50 Hz (-6 dB cutoff frequency: 29.25 Hz)
# - Filter length: 213 samples (1.664 sec)
#
# Effective window size : 16.000 (s)
# <MNELineFigure size 720x252 with 1 Axes>
# Text(0.5, 0.98, 'Filtered Data')

# %%
raw.set_montage(mne.channels.make_standard_montage('standard_alphabetic', head_size=0.095))
# Out:
# <RawArray | 3 x 161280 (1260.0 s), ~3.7 MB, data loaded>

# %%
epochs =  mne.make_fixed_length_epochs(raw, duration = 9) # Dividing raw into epoch components
data = epochs.get_data()
print(data.shape)
# Out:
# Not setting metadata
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 140 events and 1152 original time points ...
# 0 bad epochs dropped
# (140, 3, 1152)

# %%
epochs.plot_psd_topomap(ch_type='eeg', normalize=True)
# Out:
# Loading data for 140 events and 1152 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows

# %%
from mne.time_frequency import tfr_morlet, psd_multitaper, psd_welch
f, ax = plt.subplots()
psds, freqs = psd_multitaper(epochs, fmin=0, fmax=45, n_jobs=1)
psds = 10 * np.log10(psds)  # convert to dB
psds_mean = psds.mean(0).mean(0)
psds_std = psds.mean(0).std(0)

ax.plot(freqs, psds_mean, color='k')
ax.fill_between(freqs, psds_mean - psds_std, psds_mean + psds_std,
                color='k', alpha=.5)
ax.set(title='Multitaper PSD', xlabel='Frequency (Hz)',
       ylabel='Power Spectral Density (dB)')
plt.show()
# Out:
# Loading data for 140 events and 1152 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows

# %%
freqs = np.logspace(*np.log10([1, 45]), num=8)
n_cycles = freqs / 2.  # different number of cycle per frequency
power, itc = tfr_morlet(epochs, freqs=freqs, n_cycles=n_cycles, use_fft=True,
                        return_itc=True, decim=3, n_jobs=1)
# Out:
# Loading data for 140 events and 1152 original time points ...

# %%
power.plot_topo(baseline=(-0.5, 0), mode='logratio', title='Average power')
power.plot([0], baseline=(-0.5, 0), mode='logratio', title=power.ch_names[0])
power.plot([1], baseline=(-0.5, 0), mode='logratio', title=power.ch_names[1])
power.plot([2], baseline=(-0.5, 0), mode='logratio', title=power.ch_names[2])
fig, axis = plt.subplots(1, 3, figsize=(12, 8))
power.plot_topomap(ch_type='eeg', tmin=0.5, tmax=1.5, fmin=8, fmax=12,
                   baseline=(-0.5, 0), mode='logratio', axes=axis[0],
                   title='Alpha', show=False)
power.plot_topomap(ch_type='eeg', tmin=0.5, tmax=1.5, fmin=13, fmax=25,
                   baseline=(-0.5, 0), mode='logratio', axes=axis[1],
                   title='Beta', show=False)
power.plot_topomap(ch_type='eeg', tmin=0.5, tmax=1.5, fmin=26, fmax=45,
                   baseline=(-0.5, 0), mode='logratio', axes=axis[2],
                   title='Gamma', show=False)
mne.viz.tight_layout()
plt.show()
# Out:
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)

# %%
itc.plot_topo(title='Inter-Trial coherence', vmin=0., vmax=1., cmap='Reds')
# Out:
# No baseline correction applied

# %%
from mne.time_frequency import tfr_multitaper
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=freqs, use_fft=True,
                     return_itc=False, average=False, decim=2)
# Out:
# Loading data for 140 events and 1152 original time points ...
# Not setting metadata

# %%
pd.set_option('display.max_rows', 40)
df = tfr.to_data_frame(time_format=None)
df.to_csv('Cleaned_data.csv')

# %% [markdown]
# # Converting signals in Epochs

# %%
from mne import Epochs, pick_types, events_from_annotations

# %%
from mne.preprocessing import ICA, create_ecg_epochs
ica = ICA(n_components=3, max_iter='auto', random_state=97)
ica.fit(raw)
ica
# Out:
# Fitting ICA to data using 3 channels (please be patient, this may take a while)
# Selecting by number: 3 components
# Fitting ICA took 0.4s.
# <ICA | raw data decomposition, method: fastica (fit in 4 iterations on 161280 samples), 3 ICA components explaining 100.0 % of variance (3 PCA components available), channel types: eeg, no sources marked for exclusion>

# %%
#epochs = mne.make_fixed_length_epochs(final_raw, duration = 0.126) # Dividing raw into epoch components
data = epochs.get_data()
print(data.shape)
print(data)
# Out:
# Loading data for 140 events and 1152 original time points ...
# (140, 3, 1152)
# [[[-1.21430643e-17  5.31758745e-03  2.72223833e-02 ...  5.72869584e-02
#     1.20133188e-01  1.01012869e-01]
#   [-2.08166817e-17  3.68057239e-02  3.83814215e-02 ... -4.75282614e-03
#    -2.71920829e-03 -4.33900845e-03]
#   [-1.56125113e-17 -3.91181631e-02 -4.79050052e-02 ... -1.17050562e-01
#    -5.08479836e-02  3.61955453e-02]]
#
#  [[ 3.61740313e-02 -6.08168174e-04  1.24410092e-02 ...  5.53370312e-02
#     1.19616088e-01  9.38812886e-02]
#   [-2.13680933e-02 -3.55375116e-02 -1.81186462e-02 ...  1.45619068e-02
#    -1.21966129e-02 -1.72916783e-02]
#   [ 8.29838534e-02  6.94178668e-02  2.23839096e-02 ... -1.26419620e-01
#    -1.12976130e-01 -2.41711038e-02]]
#
#  [[ 1.29948392e-02 -3.01996307e-02  1.66721551e-03 ...  9.15761403e-02
#     1.20776322e-01  7.56289858e-02]
#   [ 2.25349766e-03  2.14460000e-02  2.25613078e-02 ... -3.57226978e-02
#    -3.15410287e-02 -6.26379108e-03]
#   [ 1.00404149e-01  1.85087859e-01  1.77397040e-01 ... -9.03022974e-02
#    -1.54785086e-01 -1.05985144e-01]]
#
#  ...
#
#  [[ 1.69818378e-02 -3.20237920e-02 -5.88550423e-02 ... -8.06334715e-03
#     1.13245160e-02  3.74618508e-02]
#   [-9.29799604e-02 -5.70926736e-02 -2.17478682e-02 ...  4.24784563e-02
#    -3.34126207e-03 -5.38210051e-02]
#   [ 4.54032428e-02  8.13556616e-02  6.15715888e-02 ...  8.88450426e-02
#     1.23183001e-01  9.92155180e-02]]
#
#  [[ 6.28563335e-02  6.37471840e-02  2.52196849e-02 ... -3.22554620e-02
#    -3.98109028e-02 -1.71249748e-02]
#   [-6.17828045e-02 -2.91508926e-02 -3.02524536e-03 ... -1.35434091e-03
#     2.54662351e-02  6.00219306e-02]
#   [ 2.88713768e-02 -3.09164693e-02 -4.38968043e-02 ...  1.56407098e-02
#     9.44853879e-02  1.28975303e-01]]
#
#  [[ 2.30075567e-02  4.35682497e-02  2.66268200e-02 ...  2.24542140e-02
#     5.72985698e-03  9.32413868e-18]
#   [ 6.47777450e-02  3.08349218e-02 -1.92241321e-02 ... -1.31171740e-01
#    -7.44854040e-02 -4.11996826e-17]
#   [ 8.56628554e-02  5.51733100e-03 -4.53203342e-02 ... -8.22456589e-02
#    -3.94165628e-02 -1.08420217e-17]]]

# %%
output_data = pd.read_csv('y_train.csv', header=None)
output_data = np.array(output_data.loc[:,0].tolist())
print(output_data)
# Out:
# [1 2 2 2 2 1 1 2 2 1 1 2 1 2 2 2 2 1 1 1 1 2 1 2 1 2 2 2 2 1 1 2 1 2 1 1 1
#  1 1 2 2 2 2 1 1 2 1 2 2 1 2 2 2 1 2 2 1 2 2 1 2 1 2 1 2 2 2 2 2 1 2 1 2 1
#  1 1 1 2 1 2 1 2 2 1 1 1 2 1 1 1 1 1 1 2 2 1 2 1 1 1 2 2 2 1 2 2 2 1 1 2 2
#  2 1 1 2 1 1 1 2 1 2 1 1 1 2 2 1 2 1 2 1 1 2 1 1 2 1 2 2 1]

# %% [markdown]
# # Training epochs into Machine Learning models

# %%
# !pip install scikit-learn==1.0
# !pip install mne_features
# Out:
# Requirement already satisfied: scikit-learn==1.0 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (1.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\91974\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn==1.0) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn==1.0) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn==1.0) (1.7.1)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn==1.0) (1.19.5)
# Requirement already satisfied: mne_features in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (0.2)
# Requirement already satisfied: numpy in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from mne_features) (1.19.5)
# Requirement already satisfied: mne in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from mne_features) (0.24.1)
# Requirement already satisfied: scikit-learn in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from mne_features) (1.0)
# Requirement already satisfied: numba in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from mne_features) (0.55.1)
# Requirement already satisfied: pandas in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from mne_features) (1.3.4)
# Requirement already satisfied: PyWavelets in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from mne_features) (1.3.0)
# Requirement already satisfied: scipy in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from mne_features) (1.7.1)
# Requirement already satisfied: setuptools in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from numba->mne_features) (47.1.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from numba->mne_features) (0.38.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from pandas->mne_features) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from pandas->mne_features) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->mne_features) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->mne_features) (3.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\91974\appdata\local\programs\python\python37\lib\site-packages (from python-dateutil>=2.7.3->pandas->mne_features) (1.15.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\91974\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
from mne_features.feature_extraction import extract_features
from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %% [markdown]
# ##### 1. Logistic Regression

# %%
pipe = Pipeline([('scaler', StandardScaler()),
                 ('lr', LogisticRegression(random_state=42, solver='lbfgs'))]) 
selected_funcs = {'time_corr', 'ptp_amp'}
X_new = extract_features(data, 128, selected_funcs)
kf = KFold(n_splits=2, shuffle=True, random_state=5)
scores = cross_val_score(pipe, X_new, output_data, scoring='accuracy', cv=kf)
print('Cross-validation accuracy score = %1.3f (+/- %1.5f)' % (np.mean(scores), np.std(scores)))
# Out:
# Cross-validation accuracy score = 0.507 (+/- 0.02143)
